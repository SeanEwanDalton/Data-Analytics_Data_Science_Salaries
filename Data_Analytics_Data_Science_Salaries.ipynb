# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanEwanDalton/Data-Analytics_Data_Science_Salaries/blob/main/Data_Analytics_Data_Science_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science Salaries

# %% [markdown]
# Thinking about jumping into a career in data science? What would your salary look like? Look no further.

# %% [markdown]
# ##Data Analytics and Visualisation

# %% [markdown]
# 1.   [Data source](https://github.com/SeanEwanDalton/Data-Analytics_Data_Science_Salaries_Looker/blob/main/Copy%20of%20Data%20Scientist%20Salaries%202023%20-%20ds_salaries%202.csv.csv) loaded into GSheets
# 2.   Raw data cleaned into enriched data
# 3.   Enriched data analysed in Looker
# 4.   Built the dashboard displaying salaries for different data science roles
#
# ![Screenshot 2023-06-06 at 12.12.13.png](data:image/png;base64,...)

# %% [markdown]
# ##Conclusion

# %% [markdown]
# Conclusions drawn from data analysis:
#
# 1.   Medium size companies tend to offer larger salaries
# 2.   There are lots of titles which may overlap in roles due to similar job descriptions
# 3.   Salaries have been taken from companies all over the world offering a balanced view of the global salary
# 4.   A data professional can do quite well for themselves! $$$
